# %% [markdown]
# # Fussing with a GMOS CGM^2 Mask

# %%
# imports
import numpy as np

from linetools import utils as ltu

from pypeit import pypeit
from pypeit import pypeitsetup
from pypeit import traceimage
from pypeit.core import parse

# %% [markdown]
# ## Instantiate

# %%
pypeit_file = '/scratch/REDUX/Gemini/J1059+1441/gemini_gmos_north_e2v_setup_A/gemini_gmos_north_e2v_setup_A.pypeit'
pypeitSetup = pypeitsetup.PypeItSetup.from_pypeit_file(pypeit_file)
# Out:
# [INFO]    :: util.py 431 parse_pypeit_file() - Loading the reduction file
# [INFO]    :: util.py 456 parse_pypeit_file() - Found 5 raw data frames
# [INFO]    :: util.py 468 parse_pypeit_file() - Input file loaded successfully

# %%
pypeIt = pypeit.instantiate_me(pypeitSetup.spectrograph, verbosity=2, overwrite=True, show=True) #, logname=logname, show=args.show)

# %% [markdown]
# ## Setup

# %%
redux_dir = '/scratch/REDUX/Gemini/J1059+1441/gemini_gmos_north_e2v_setup_A/'

# %%
pypeIt.init_setup(pypeit_file, redux_dir, calibration_check=True)
# Out:
# [INFO]    :: util.py 431 parse_pypeit_file() - Loading the reduction file
# [INFO]    :: util.py 456 parse_pypeit_file() - Found 5 raw data frames
# [INFO]    :: util.py 468 parse_pypeit_file() - Input file loaded successfully
# [WARNING] :: spectrograph.py 449 check_headers() - Specific header keyword checks have not been implemented for gemini_gmos_north_e2v.
# [INFO]    :: metadata.py 192 _build() - Successfully loaded headers for file:
#              /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0251.fits
# [WARNING] :: spectrograph.py 449 check_headers() - Specific header keyword checks have not been implemented for gemini_gmos_north_e2v.
# [INFO]    :: metadata.py 192 _build() - Successfully loaded headers for file:
#              /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0095.fits
# [WARNING] :: spectrograph.py 449 check_headers() - Specific header keyword checks have not been implemented for gemini_gmos_north_e2v.
# [INFO]    :: metadata.py 192 _build() - Successfully loaded headers for file:
#              /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0096.fits
# [WARNING] :: spectrograph.py 449 check_headers() - Specific header keyword checks have not been implemented for gemini_gmos_north_e2v.
# [INFO]    :: metadata.py 192 _build() - Successfully loaded headers for file:
#              /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0099.fits
# [WARNING] :: spectrograph.py 449 check_headers() - Specific header keyword checks have not been implemented for gemini_gmos_north_e2v.
# [INFO]    :: metadata.py 192 _build() - Successfully loaded headers for file:
#              /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0094.fits
# [INFO]    :: metadata.py 195 _build() - Headers loaded for 5 files successfully
# [INFO]    :: metadata.py 426 get_frame_types() - Typing files
# [INFO]    :: metadata.py 433 get_frame_types() - Using user-provided frame types.
# [INFO]    :: metadata.py 583 match_to_science() - Matching calibrations to Science frames
# [INFO]    :: metadata.py 604 match_to_science() - ==================================================
# [INFO]    :: metadata.py 605 match_to_science() - Matching calibrations to frame: J1059+1441
# [INFO]    :: metadata.py 637 match_to_science() -    No pinhole frames are required.  Not matching...
# [INFO]    :: metadata.py 660 match_to_science() -   Found 0 bias frame for J1059+1441 (5 required)
# [WARNING] :: framematch.py 398 match_warnings() -   Only 0/5 bias frames for J1059+1441
# [INFO]    :: metadata.py 660 match_to_science() -   Found 1 arc frame for J1059+1441 (1 required)
# [INFO]    :: metadata.py 660 match_to_science() -   Found 3 trace frame for J1059+1441 (3 required)
# [INFO]    :: metadata.py 637 match_to_science() -    No standard frames are required.  Not matching...
# [INFO]    :: metadata.py 660 match_to_science() -   Found 3 pixelflat frame for J1059+1441 (3 required)
# [INFO]    :: metadata.py 619 match_to_science() -   Dark frames not required.  Not matching...
# [INFO]    :: metadata.py 683 match_to_science() - Science frames successfully matched to calibration frames.
# [INFO]    :: metadata.py 532 write() - Writing fits file metadata to /scratch/REDUX/Gemini/J1059+1441/gemini_gmos_north_e2v_setup_A/gemini_gmos_north_e2v_setup_A.lst.
# [INFO]    :: pypeitsetup.py 483 run() - Inspect the .calib file: /scratch/REDUX/Gemini/J1059+1441/gemini_gmos_north_e2v_setup_A/gemini_gmos_north_e2v_setup_A.calib
# [INFO]    :: pypeitsetup.py 484 run() - *********************************************************
# [INFO]    :: pypeitsetup.py 485 run() - Calibration check complete and successful!
# [INFO]    :: pypeitsetup.py 487 run() - *********************************************************
# [INFO]    :: pypeit.py 520 init_setup() - Setting reduction path to /scratch/REDUX/Gemini/J1059+1441/gemini_gmos_north_e2v_setup_A/
# [INFO]    :: paths.py 38 make_dirs() - Creating Science directory
# [INFO]    :: paths.py 41 make_dirs() - The following directory already exists:
#              /scratch/REDUX/Gemini/J1059+1441/gemini_gmos_north_e2v_setup_A/Science
# [INFO]    :: paths.py 63 make_dirs() - Creating Object directories
# [INFO]    :: paths.py 66 make_dirs() - Creating Master Calibrations directory
# [INFO]    :: paths.py 86 make_dirs() - Creating QA directory
# [WARNING] :: paths.py 89 make_dirs() - Pre-existing QA plots will be overwritten

# %% [markdown]
# # Reduce

# %%
pypeIt.caliBrate.par.keys()
# Out:
# ['caldir',
#  'masters',
#  'setup',
#  'trim',
#  'badpix',
#  'biasframe',
#  'darkframe',
#  'arcframe',
#  'pixelflatframe',
#  'pinholeframe',
#  'traceframe',
#  'standardframe',
#  'flatfield',
#  'wavelengths',
#  'slits',
#  'tilts']

# %%
pypeIt.caliBrate.par['slits']['min_slit_width'] = 4.0
pypeIt.caliBrate.par['slits']
# Out:
# Parameter       Value       Default     Type        Callable
# ------------------------------------------------------------
# function        legendre    legendre    str         False
# polyorder       3           3           int         False
# medrep          0           0           int         False
# number          -1          -1          int         False
# trim            3, 3        3, 3        tuple       False
# maxgap          None        None        int         False
# maxshift        0.15        0.15        int, float  False
# pad             0           0           int         False
# sigdetect       20.0        20.0        int, float  False
# fracignore      0.02        0.01        float       False
# min_slit_width  4.0         6.0         float       False
# diffpolyorder   2           2           int         False
# single          []          []          list        False
# sobel_mode      nearest     nearest     str         False
# pcatype         pixel       pixel       str         False
# pcapar          3, 2, 1, 0  3, 2, 1, 0  list        False
# pcaextrap       0, 0        0, 0        list        False

# %%
pypeIt.reduce_all()
# Out:
# [INFO]    :: pypeit.py 325 reduce_exposure() - Reducing file N20150116S0094.fits, target J1059+1441
# [INFO]    :: pypeit.py 339 reduce_exposure() - Working on detector 1
# [INFO]    :: calibrations.py 194 get_arc() - Preparing a master arc frame
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0251.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0251.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0251.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0251.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0251.fits
# [INFO]    :: processimages.py 275 bias_subtract() - Bias subtracting your image(s)
# [INFO]    :: processimages.py 288 bias_subtract() - Using overscan to subtact
# [INFO]    :: masters.py 368 save_master() - Saving master arc frame as:
#              /scratch/REDUX/Gemini/J1059+1441/gemini_gmos_north_e2v_setup_A/MF_gemini_gmos_north_e2v/MasterArc_A_01_aa.fits
# [INFO]    :: masters.py 386 save_master() - Writing header information
# [WARNING] :: masters.py 397 save_master() - Overwriting file:
#              /scratch/REDUX/Gemini/J1059+1441/gemini_gmos_north_e2v_setup_A/MF_gemini_gmos_north_e2v/MasterArc_A_01_aa.fits
# [INFO]    :: masters.py 401 save_master() - Master arc frame saved successfully:
#              /scratch/REDUX/Gemini/J1059+1441/gemini_gmos_north_e2v_setup_A/MF_gemini_gmos_north_e2v/MasterArc_A_01_aa.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0094.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0094.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0094.fits
# [INFO]    :: pixels.py 37 gen_pixloc() - Deriving physical pixel locations on the detector
# [INFO]    :: pixels.py 40 gen_pixloc() - Pixel gap in the dispersion direction = 0.000
# [INFO]    :: pixels.py 41 gen_pixloc() - Pixel size in the dispersion direction = 1.000
# [INFO]    :: pixels.py 44 gen_pixloc() - Pixel gap in the spatial direction = 0.000
# [INFO]    :: pixels.py 45 gen_pixloc() - Pixel size in the spatial direction = 1.000
# [INFO]    :: pixels.py 50 gen_pixloc() - Saving pixel locations
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0095.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0096.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0099.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0095.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0095.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0095.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0095.fits
# [INFO]    :: processimages.py 275 bias_subtract() - Bias subtracting your image(s)
# [INFO]    :: processimages.py 288 bias_subtract() - Using overscan to subtact
# [INFO]    :: processimages.py 288 bias_subtract() - Using overscan to subtact
# [INFO]    :: processimages.py 288 bias_subtract() - Using overscan to subtact
# [INFO]    :: combine.py 62 comb_frames() - Combining 3 trace_image frames
# [WORK IN ]::
# [PROGRESS]:: combine.py 66 comb_frames() - lscomb feature has not been included here yet...
# [INFO]    :: combine.py 95 comb_frames() - Finding saturated and non-linear pixels
# [INFO]    :: combine.py 119 comb_frames() - Rejecting cosmic rays
# [INFO]    :: combine.py 163 comb_frames() - Not rejecting any low/high pixels
# [INFO]    :: combine.py 171 comb_frames() - Rejecting deviant pixels
# [INFO]    :: combine.py 188 comb_frames() - Combining frames with a weightmean operation
# [INFO]    :: combine.py 201 comb_frames() - Replacing completely masked pixels with the maxnonsat value of the input frames
# [INFO]    :: combine.py 215 comb_frames() - 3 trace_image frames combined successfully!
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0095.fits
# [INFO]    :: gemini_gmos.py 488 read_gmos() - Reading GMOS file: /scratch/REDUX/Gemini/J1059+1441/Raw/N20150116S0095.fits
# [WARNING] :: procimg.py 456 gain_frame() - Should probably be measuring the gain across the amplifier boundary
# [INFO]    :: trace_slits.py 813 edgearr_from_binarr() - Detecting slit edges in the mstrace image
# [INFO]    :: trace_slits.py 874 edgearr_from_binarr() - Applying bad pixel mask
# [INFO]    :: trace_slits.py 933 edgearr_add_left_right() - 49 left edges and 48 right edges were found in the trace
# [INFO]    :: trace_slits.py 960 edgearr_add_left_right() - Assigning slit edge traces
# [INFO]    :: traceslits.py 361 _assign_edges() - Assigning left slit edges
#              trace_slits.py 160 assign_slits() - Outer left edge loop, Iteration 1
#              trace_slits.py 298 assign_slits() -   Inner loop, Iteration 1, 49 left edges assigned (49 total)
#              trace_slits.py 160 assign_slits() - Outer left edge loop, Iteration 2
#              trace_slits.py 298 assign_slits() -   Inner loop, Iteration 1, 49 left edges assigned (49 total)
# [INFO]    :: traceslits.py 369 _assign_edges() - Assigning right slit edges
#              trace_slits.py 160 assign_slits() - Outer right edge loop, Iteration 1
#              trace_slits.py 298 assign_slits() -   Inner loop, Iteration 1, 47 right edges assigned (47 total)
#              trace_slits.py 298 assign_slits() -   Inner loop, Iteration 2, 1 right edges assigned (48 total)
#              trace_slits.py 160 assign_slits() - Outer right edge loop, Iteration 2
#              trace_slits.py 298 assign_slits() -   Inner loop, Iteration 1, 47 right edges assigned (47 total)
#              trace_slits.py 298 assign_slits() -   Inner loop, Iteration 2, 1 right edges assigned (48 total)
# [INFO]    :: trace_slits.py 1157 edgearr_final_left_right() - 49 left edges and 48 right edges were found in the trace
# [INFO]    :: trace_slits.py 560 edgearr_tcrude() - Crude tracing the edges
# [WARNING] :: trace_slits.py 472 edgearr_mslit_sync() - Missing a right edge for slit with left edge at 1442
# [WARNING] :: trace_slits.py 473 edgearr_mslit_sync() - Adding in a corresponding right edge!
# [INFO]    :: trace_slits.py 1309 fit_edges() - Fitting left slit traces
# [INFO]    :: trace_slits.py 1311 fit_edges() - Fitting right slit traces
# [INFO]    :: traceslits.py 797 _synchronize() - Synchronizing left and right slit traces
# [INFO]    :: trace_slits.py 2437 synchronize_edges() - Relabelling slit edges
# [WORK IN ]::
# [PROGRESS]:: trace_slits.py 2080 pca_pixel_slit_edges() - May need to do a check here to make sure ofit is reasonable
# [INFO]    :: trace_slits.py 2086 pca_pixel_slit_edges() - Performing a PCA on the slit traces
#              pca.py 98 basis() -   Reduced chi-squared = 2.109613E-07
# [INFO]    :: traceslits.py 845 _trim_slits() - Slit 13 has width = 2.1837675380609904 < less than min_slit_width = 4.0 arcseconds - ignoring this slit
# [INFO]    :: traceslits.py 845 _trim_slits() - Slit 39 has width = 2.1278821357908866 < less than min_slit_width = 4.0 arcseconds - ignoring this slit
# [INFO]    :: traceslits.py 845 _trim_slits() - Slit 42 has width = 1.871624592335081 < less than min_slit_width = 4.0 arcseconds - ignoring this slit
# [INFO]    :: traceslits.py 845 _trim_slits() - Slit 49 has width = 2.162858407606137 < less than min_slit_width = 4.0 arcseconds - ignoring this slit
# [INFO]    :: traceslits.py 535 _make_pixel_arrays() - Converting physical trace locations to nearest pixel
# [INFO]    :: traceslits.py 542 _make_pixel_arrays() - Identifying the pixels belonging to each slit
# [INFO]    :: traceslits.py 933 save_master() - Wrote TraceSlit arrays to /scratch/REDUX/Gemini/J1059+1441/gemini_gmos_north_e2v_setup_A/MF_gemini_gmos_north_e2v/MasterTrace_A_01_aa.fits
# [INFO]    :: traceslits.py 935 save_master() - gzip compressing /scratch/REDUX/Gemini/J1059+1441/gemini_gmos_north_e2v_setup_A/MF_gemini_gmos_north_e2v/MasterTrace_A_01_aa.fits
# [INFO]    :: traceslits.py 949 save_master() - Writing TraceSlit dict to /scratch/REDUX/Gemini/J1059+1441/gemini_gmos_north_e2v_setup_A/MF_gemini_gmos_north_e2v/MasterTrace_A_01_aa.json
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 1
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 2
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 3
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 4
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 5
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 6
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 7
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 8
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 9
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 10
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 11
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 12
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 13
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 14
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 15
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 16
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 17
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 18
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 19
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 20
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 21
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 22
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 23
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 24
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 25
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 26
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 27
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 28
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 29
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 30
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 31
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 32
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 33
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 34
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 35
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 36
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 37
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 38
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 39
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 40
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 41
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 42
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 43
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 44
# [INFO]    :: arc.py 150 get_censpec() - Extracting an approximate arc spectrum at the centre of slit 45
# [INFO]    :: arc.py 73 setup_param() - Loading line list using CuI,ArI,ArII lamps
# [INFO]    :: autoid.py 408 __init__() - Using brute force pattern matching algorithm to wavelength calibrate
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [WARNING] :: autoid.py 1425 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 1/45:
#                Poor RMS (0.304)! Attempting to cross match.
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 2/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 23
#                Number of lines analyzed     = 17
#                Number of pattern matches    = 12
#                Best central wavelength      = 4794.71A
#                Best dispersion              = 1.33833A/pix
#                Best wave/disp               = 3582.6
#                Final RMS of fit             = 0.161197
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 3/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 24
#                Number of lines analyzed     = 21
#                Number of pattern matches    = 13
#                Best central wavelength      = 4967.35A
#                Best dispersion              = 1.33833A/pix
#                Best wave/disp               = 3711.61
#                Final RMS of fit             = 0.157713
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [WARNING] :: autoid.py 1425 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 4/45:
#                Poor RMS (0.311)! Attempting to cross match.
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 5/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 24
#                Number of lines analyzed     = 15
#                Number of pattern matches    = 8
#                Best central wavelength      = 6521.19A
#                Best dispersion              = 1.32758A/pix
#                Best wave/disp               = 4912.08
#                Final RMS of fit             = 0.141852
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 6/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 23
#                Number of lines analyzed     = 15
#                Number of pattern matches    = 9
#                Best central wavelength      = 6521.19A
#                Best dispersion              = 1.34374A/pix
#                Best wave/disp               = 4853.03
#                Final RMS of fit             = 0.174712
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 7/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 26
#                Number of lines analyzed     = 23
#                Number of pattern matches    = 18
#                Best central wavelength      = 5744.27A
#                Best dispersion              = 1.33833A/pix
#                Best wave/disp               = 4292.12
#                Final RMS of fit             = 0.17739
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 8/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 30
#                Number of lines analyzed     = 24
#                Number of pattern matches    = 19
#                Best central wavelength      = 6262.22A
#                Best dispersion              = 1.34374A/pix
#                Best wave/disp               = 4660.3
#                Final RMS of fit             = 0.249243
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 9/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 24
#                Number of lines analyzed     = 17
#                Number of pattern matches    = 14
#                Best central wavelength      = 4363.09A
#                Best dispersion              = 1.34374A/pix
#                Best wave/disp               = 3246.98
#                Final RMS of fit             = 0.0984255
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [WARNING] :: autoid.py 1425 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 10/45:
#                Poor RMS (0.323)! Attempting to cross match.
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 11/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 26
#                Number of lines analyzed     = 23
#                Number of pattern matches    = 14
#                Best central wavelength      = 4967.35A
#                Best dispersion              = 1.33833A/pix
#                Best wave/disp               = 3711.61
#                Final RMS of fit             = 0.189434
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 12/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 27
#                Number of lines analyzed     = 19
#                Number of pattern matches    = 15
#                Best central wavelength      = 5024.9A
#                Best dispersion              = 1.33295A/pix
#                Best wave/disp               = 3769.77
#                Final RMS of fit             = 0.111958
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 13/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 24
#                Number of lines analyzed     = 19
#                Number of pattern matches    = 13
#                Best central wavelength      = 5974.47A
#                Best dispersion              = 1.35462A/pix
#                Best wave/disp               = 4410.46
#                Final RMS of fit             = 0.111973
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 14/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 27
#                Number of lines analyzed     = 24
#                Number of pattern matches    = 24
#                Best central wavelength      = 5140A
#                Best dispersion              = 1.34374A/pix
#                Best wave/disp               = 3825.16
#                Final RMS of fit             = 0.252376
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [WARNING] :: autoid.py 1425 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 15/45:
#                Poor RMS (0.380)! Attempting to cross match.
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [WARNING] :: autoid.py 1425 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 16/45:
#                Poor RMS (0.336)! Attempting to cross match.
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 17/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 20
#                Number of lines analyzed     = 17
#                Number of pattern matches    = 9
#                Best central wavelength      = 4679.61A
#                Best dispersion              = 1.34916A/pix
#                Best wave/disp               = 3468.52
#                Final RMS of fit             = 0.176724
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 18/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 24
#                Number of lines analyzed     = 20
#                Number of pattern matches    = 14
#                Best central wavelength      = 6032.02A
#                Best dispersion              = 1.32758A/pix
#                Best wave/disp               = 4543.61
#                Final RMS of fit             = 0.263963
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 19/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 23
#                Number of lines analyzed     = 20
#                Number of pattern matches    = 16
#                Best central wavelength      = 6204.67A
#                Best dispersion              = 1.34916A/pix
#                Best wave/disp               = 4598.89
#                Final RMS of fit             = 0.19798
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [WARNING] :: autoid.py 1425 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 20/45:
#                Poor RMS (0.320)! Attempting to cross match.
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [WARNING] :: autoid.py 1425 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 21/45:
#                Poor RMS (0.350)! Attempting to cross match.
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 22/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 25
#                Number of lines analyzed     = 22
#                Number of pattern matches    = 18
#                Best central wavelength      = 5715.5A
#                Best dispersion              = 1.34374A/pix
#                Best wave/disp               = 4253.44
#                Final RMS of fit             = 0.217342
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [WARNING] :: autoid.py 1425 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 23/45:
#                Poor RMS (0.347)! Attempting to cross match.
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 24/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 23
#                Number of lines analyzed     = 19
#                Number of pattern matches    = 13
#                Best central wavelength      = 4938.58A
#                Best dispersion              = 1.33295A/pix
#                Best wave/disp               = 3705.01
#                Final RMS of fit             = 0.204018
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 25/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 25
#                Number of lines analyzed     = 21
#                Number of pattern matches    = 18
#                Best central wavelength      = 5312.65A
#                Best dispersion              = 1.34374A/pix
#                Best wave/disp               = 3953.64
#                Final RMS of fit             = 0.229908
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 26/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 24
#                Number of lines analyzed     = 16
#                Number of pattern matches    = 11
#                Best central wavelength      = 4996.13A
#                Best dispersion              = 1.33295A/pix
#                Best wave/disp               = 3748.19
#                Final RMS of fit             = 0.0643444
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 27/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 23
#                Number of lines analyzed     = 19
#                Number of pattern matches    = 10
#                Best central wavelength      = 4967.35A
#                Best dispersion              = 1.33833A/pix
#                Best wave/disp               = 3711.61
#                Final RMS of fit             = 0.147582
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 28/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 24
#                Number of lines analyzed     = 21
#                Number of pattern matches    = 16
#                Best central wavelength      = 5916.92A
#                Best dispersion              = 1.33295A/pix
#                Best wave/disp               = 4438.98
#                Final RMS of fit             = 0.254453
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 29/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 26
#                Number of lines analyzed     = 24
#                Number of pattern matches    = 18
#                Best central wavelength      = 5427.75A
#                Best dispersion              = 1.34916A/pix
#                Best wave/disp               = 4023.04
#                Final RMS of fit             = 0.219287
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 30/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 28
#                Number of lines analyzed     = 25
#                Number of pattern matches    = 22
#                Best central wavelength      = 5111.23A
#                Best dispersion              = 1.33833A/pix
#                Best wave/disp               = 3819.11
#                Final RMS of fit             = 0.274002
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 31/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 24
#                Number of lines analyzed     = 19
#                Number of pattern matches    = 13
#                Best central wavelength      = 4334.31A
#                Best dispersion              = 1.34916A/pix
#                Best wave/disp               = 3212.59
#                Final RMS of fit             = 0.280185
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [WARNING] :: autoid.py 1425 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 32/45:
#                Poor RMS (0.313)! Attempting to cross match.
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 33/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 25
#                Number of lines analyzed     = 22
#                Number of pattern matches    = 15
#                Best central wavelength      = 5744.27A
#                Best dispersion              = 1.33833A/pix
#                Best wave/disp               = 4292.12
#                Final RMS of fit             = 0.234545
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 34/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 18
#                Number of lines analyzed     = 4
#                Number of pattern matches    = 7
#                Best central wavelength      = 6377.32A
#                Best dispersion              = 0.414055A/pix
#                Best wave/disp               = 15402.1
#                Final RMS of fit             = 5.70681e-12
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 35/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 27
#                Number of lines analyzed     = 25
#                Number of pattern matches    = 18
#                Best central wavelength      = 5111.23A
#                Best dispersion              = 1.33295A/pix
#                Best wave/disp               = 3834.54
#                Final RMS of fit             = 0.288231
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 36/45:
#                Pixels anitcorrelate with wavelength
#                Number of lines recovered    = 24
#                Number of lines analyzed     = 4
#                Number of pattern matches    = 4
#                Best central wavelength      = 7269.33A
#                Best dispersion              = 0.865902A/pix
#                Best wave/disp               = 8395.1
#                Final RMS of fit             = 3.32148e-12
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [WARNING] :: autoid.py 1425 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 37/45:
#                Poor RMS (0.328)! Attempting to cross match.
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [WARNING] :: autoid.py 1425 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 38/45:
#                Poor RMS (0.331)! Attempting to cross match.
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 39/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 23
#                Number of lines analyzed     = 21
#                Number of pattern matches    = 15
#                Best central wavelength      = 6204.67A
#                Best dispersion              = 1.33295A/pix
#                Best wave/disp               = 4654.85
#                Final RMS of fit             = 0.203606
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 40/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 25
#                Number of lines analyzed     = 24
#                Number of pattern matches    = 20
#                Best central wavelength      = 5456.52A
#                Best dispersion              = 1.34374A/pix
#                Best wave/disp               = 4060.71
#                Final RMS of fit             = 0.274966
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 41/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 25
#                Number of lines analyzed     = 20
#                Number of pattern matches    = 19
#                Best central wavelength      = 5773.05A
#                Best dispersion              = 1.34374A/pix
#                Best wave/disp               = 4296.26
#                Final RMS of fit             = 0.119617
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 42/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 24
#                Number of lines analyzed     = 20
#                Number of pattern matches    = 13
#                Best central wavelength      = 5024.9A
#                Best dispersion              = 1.33295A/pix
#                Best wave/disp               = 3769.77
#                Final RMS of fit             = 0.228126
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 43/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 22
#                Number of lines analyzed     = 20
#                Number of pattern matches    = 14
#                Best central wavelength      = 5888.15A
#                Best dispersion              = 1.32758A/pix
#                Best wave/disp               = 4435.24
#                Final RMS of fit             = 0.240945
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 44/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 23
#                Number of lines analyzed     = 19
#                Number of pattern matches    = 17
#                Best central wavelength      = 4247.99A
#                Best dispersion              = 1.34374A/pix
#                Best wave/disp               = 3161.32
#                Final RMS of fit             = 0.202031
#              ---------------------------------------------------
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: arc.py 497 detect_lines() - Detecting lines...isolating the strongest, nonsaturated lines
# [INFO]    :: autoid.py 1445 report_prelim() - ---------------------------------------------------
#              Preliminary report for slit 45/45:
#                Pixels correlate with wavelength
#                Number of lines recovered    = 21
#                Number of lines analyzed     = 17
#                Number of pattern matches    = 8
#                Best central wavelength      = 6319.77A
#                Best dispersion              = 1.35462A/pix
#                Best wave/disp               = 4665.36
#                Final RMS of fit             = 0.150403
#              ---------------------------------------------------
# [WARNING] :: autoid.py 810 cross_match() - ---------------------------------------------------
#              Cross-match report for slit 1/45:
#                Poor RMS (41.125)! Will try cross matching iteratively
#              ---------------------------------------------------
# [WARNING] :: autoid.py 810 cross_match() - ---------------------------------------------------
#              Cross-match report for slit 4/45:
#                Poor RMS (0.312)! Will try cross matching iteratively
#              ---------------------------------------------------
# [WARNING] :: autoid.py 810 cross_match() - ---------------------------------------------------
#              Cross-match report for slit 10/45:
#                Poor RMS (140.198)! Will try cross matching iteratively
# ...
# [INFO]    :: flat.py 60 tweak_slit_edges() - Tweaking left slit boundary by 3.000 %, or   1.055 pixels
# [INFO]    :: flat.py 68 tweak_slit_edges() - Right threshold = 0.932 --  or 93.000 % of right side max of illumination function = 1.002
# [INFO]    :: flat.py 76 tweak_slit_edges() - Tweaking right slit boundary by 3.900 %, or   1.371 pixels
# [INFO]    :: flat.py 363 fit_flat() - Performing illumination + scattered light flat field fit
# [INFO]    :: utils.py 324 bspline_profile() - Fitting npoly =  4 profile basis functions, nin=34341 good pixels
# [INFO]    :: utils.py 325 bspline_profile() - ******************************  Iter  Chi^2  # rejected  Rel. fact   ******************************
# [INFO]    :: utils.py 326 bspline_profile() -                               ----  -----  ----------  ---------
# [INFO]    :: utils.py 400 bspline_profile() -                                 1   6.283     2031        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 2   1.999     2155        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 3   1.905     2216        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 4   1.858     2242        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 5   1.838     2247        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 6   1.836     2248        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 7   1.835     2250        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 8   1.834     2252        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 9   1.833     2252        1.00
# [INFO]    :: utils.py 406 bspline_profile() - ***************************************************************************************************
# [INFO]    :: utils.py 409 bspline_profile() - Final fit after  9 iterations: reduced_chi =    1.833, rejected =    2252, relative_factor =   1.00
# [INFO]    :: flatfield.py 257 run() - Computing flat field image for slit: 44
# [INFO]    :: flat.py 238 fit_flat() - Spectral fit of flatfield for 28817 pixels
# [INFO]    :: utils.py 324 bspline_profile() - Fitting npoly =  1 profile basis functions, nin=28817 good pixels
# [INFO]    :: utils.py 325 bspline_profile() - ******************************  Iter  Chi^2  # rejected  Rel. fact   ******************************
# [INFO]    :: utils.py 326 bspline_profile() -                               ----  -----  ----------  ---------
# [INFO]    :: utils.py 400 bspline_profile() -                                 1   0.005        1        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 2   0.005        1        1.00
# [INFO]    :: utils.py 406 bspline_profile() - ***************************************************************************************************
# [INFO]    :: utils.py 409 bspline_profile() - Final fit after  2 iterations: reduced_chi =    0.005, rejected =       1, relative_factor =   1.00
# [INFO]    :: utils.py 324 bspline_profile() - Fitting npoly =  1 profile basis functions, nin=40868 good pixels
# [INFO]    :: utils.py 325 bspline_profile() - ******************************  Iter  Chi^2  # rejected  Rel. fact   ******************************
# [INFO]    :: utils.py 326 bspline_profile() -                               ----  -----  ----------  ---------
# [WARNING] :: pydl.py 853 cholesky_band() - Found 15 bad entries: [ 3  4  5  6  7  8 13 14 15 16 17 18 23 24 33]
# [INFO]    :: utils.py 403 bspline_profile() -                                 1    ---    ---    ---    ---
# [INFO]    :: utils.py 400 bspline_profile() -                                 2   0.000        0        1.00
# [INFO]    :: utils.py 406 bspline_profile() - ***************************************************************************************************
# [INFO]    :: utils.py 409 bspline_profile() - Final fit after  2 iterations: reduced_chi =    0.000, rejected =       0, relative_factor =   1.00
# [INFO]    :: flat.py 48 tweak_slit_edges() - Tweaking slit boundaries using slit illumination function
# [INFO]    :: flat.py 53 tweak_slit_edges() - Left threshold = 0.955 --  or 93.000 % of left side max of illumination function = 1.026
# [INFO]    :: flat.py 60 tweak_slit_edges() - Tweaking left slit boundary by -0.800 %, or  -0.275 pixels
# [INFO]    :: flat.py 68 tweak_slit_edges() - Right threshold = 0.922 --  or 93.000 % of right side max of illumination function = 0.991
# [INFO]    :: flat.py 76 tweak_slit_edges() - Tweaking right slit boundary by -1.100 %, or  -0.378 pixels
# [INFO]    :: flat.py 363 fit_flat() - Performing illumination + scattered light flat field fit
# [INFO]    :: utils.py 324 bspline_profile() - Fitting npoly =  4 profile basis functions, nin=35881 good pixels
# [INFO]    :: utils.py 325 bspline_profile() - ******************************  Iter  Chi^2  # rejected  Rel. fact   ******************************
# [INFO]    :: utils.py 326 bspline_profile() -                               ----  -----  ----------  ---------
# [INFO]    :: utils.py 400 bspline_profile() -                                 1  13.058     9319        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 2   3.723     9629        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 3   3.536     9718        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 4   3.489     9748        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 5   3.474     9761        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 6   3.467     9769        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 7   3.463     9777        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 8   3.459     9782        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 9   3.457     9788        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                10   3.454     9792        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                11   3.452     9794        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                12   3.451     9796        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                13   3.450     9796        1.00
# [INFO]    :: utils.py 406 bspline_profile() - ***************************************************************************************************
# [INFO]    :: utils.py 409 bspline_profile() - Final fit after 13 iterations: reduced_chi =    3.450, rejected =    9796, relative_factor =   1.00
# [INFO]    :: flatfield.py 257 run() - Computing flat field image for slit: 45
# [INFO]    :: flat.py 238 fit_flat() - Spectral fit of flatfield for 30328 pixels
# [INFO]    :: utils.py 324 bspline_profile() - Fitting npoly =  1 profile basis functions, nin=30328 good pixels
# [INFO]    :: utils.py 325 bspline_profile() - ******************************  Iter  Chi^2  # rejected  Rel. fact   ******************************
# [INFO]    :: utils.py 326 bspline_profile() -                               ----  -----  ----------  ---------
# [INFO]    :: utils.py 400 bspline_profile() -                                 1   0.001        1        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 2   0.001        1        1.00
# [INFO]    :: utils.py 406 bspline_profile() - ***************************************************************************************************
# [INFO]    :: utils.py 409 bspline_profile() - Final fit after  2 iterations: reduced_chi =    0.001, rejected =       1, relative_factor =   1.00
# [INFO]    :: utils.py 324 bspline_profile() - Fitting npoly =  1 profile basis functions, nin=47686 good pixels
# [INFO]    :: utils.py 325 bspline_profile() - ******************************  Iter  Chi^2  # rejected  Rel. fact   ******************************
# [INFO]    :: utils.py 326 bspline_profile() -                               ----  -----  ----------  ---------
# [INFO]    :: utils.py 400 bspline_profile() -                                 1   0.000        0        1.00
# [INFO]    :: utils.py 406 bspline_profile() - ***************************************************************************************************
# [INFO]    :: utils.py 409 bspline_profile() - Final fit after  1 iterations: reduced_chi =    0.000, rejected =       0, relative_factor =   1.00
# [INFO]    :: flat.py 48 tweak_slit_edges() - Tweaking slit boundaries using slit illumination function
# [INFO]    :: flat.py 53 tweak_slit_edges() - Left threshold = 0.933 --  or 93.000 % of left side max of illumination function = 1.004
# [INFO]    :: flat.py 60 tweak_slit_edges() - Tweaking left slit boundary by 3.000 %, or   1.055 pixels
# [INFO]    :: flat.py 68 tweak_slit_edges() - Right threshold = 0.931 --  or 93.000 % of right side max of illumination function = 1.001
# [INFO]    :: flat.py 76 tweak_slit_edges() - Tweaking right slit boundary by 3.500 %, or   1.231 pixels
# [INFO]    :: flat.py 363 fit_flat() - Performing illumination + scattered light flat field fit
# [INFO]    :: utils.py 324 bspline_profile() - Fitting npoly =  4 profile basis functions, nin=34344 good pixels
# [INFO]    :: utils.py 325 bspline_profile() - ******************************  Iter  Chi^2  # rejected  Rel. fact   ******************************
# [INFO]    :: utils.py 326 bspline_profile() -                               ----  -----  ----------  ---------
# [INFO]    :: utils.py 400 bspline_profile() -                                 1   4.797     1477        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 2   1.752     1553        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 3   1.693     1571        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 4   1.683     1577        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 5   1.680     1578        1.00
# [INFO]    :: utils.py 400 bspline_profile() -                                 6   1.680     1578        1.00
# [INFO]    :: utils.py 406 bspline_profile() - ***************************************************************************************************
# [INFO]    :: utils.py 409 bspline_profile() - Final fit after  6 iterations: reduced_chi =    1.680, rejected =    1578, relative_factor =   1.00
# ---------------------------------------------------------------------------
# Fault                                     Traceback (most recent call last)
# <ipython-input-8-84c6e515cd69> in <module>()
# ----> 1 pypeIt.reduce_all()
#
# /data/Projects/Python/PypeIt/pypeit/pypeit.py in reduce_all(self, reuse_masters)
#     227
#     228         for kk,sci_ID in enumerate(all_sci_ID):
# --> 229             sci_dict = self.reduce_exposure(sci_ID, reuse_masters=reuse_masters)
#     230             # Save
#     231             scidx = self.fitstbl.find_frames('science', sci_ID=sci_ID, index=True)[0]
#
# /data/Projects/Python/PypeIt/pypeit/pypeit.py in reduce_exposure(self, sci_ID, reuse_masters)
#     341
#     342             # Calibrate
# --> 343             self.calibrate_one(sci_ID, det)
#     344
#     345             # Init ScienceImage class
#
# /data/Projects/Python/PypeIt/pypeit/pypeit.py in calibrate_one(self, sci_ID, det)
#     695         self.caliBrate.reset(self.setup, det, sci_ID, self.par['calibrations'])
#     696         # Run em
# --> 697         self.caliBrate.run_the_steps()
#     698
#     699         msgs.info("Successful Calibration!")
#
# /data/Projects/Python/PypeIt/pypeit/calibrations.py in run_the_steps(self)
#     692         """
#     693         for step in self.steps:
# --> 694             getattr(self, 'get_{:s}'.format(step))()
#     695
#     696     # This is general to any attribute
#
# /data/Projects/Python/PypeIt/pypeit/calibrations.py in get_flats(self, show)
#     352         if self.mspixflatnrm is None and len(pixflat_image_files) != 0:
#     353             # Run
# --> 354             self.mspixflatnrm, self.msillumflat = self.flatField.run(show=self.show)
#     355
#     356             # If we tweaked the slits, update the tilts_dict and
#
# /data/Projects/Python/PypeIt/pypeit/flatfield.py in run(self, debug, show)
#     293         if show:
#     294             # Global skysub is the first step in a new extraction so clear the channels here
# --> 295             self.show(slits=True, wcs_match = True)
#     296
#     297         # Return
#
# /data/Projects/Python/PypeIt/pypeit/flatfield.py in show(self, slits, wcs_match)
#     302     def show(self, slits = True, wcs_match = True):
#     303
# --> 304         viewer, ch = ginga.show_image(self.mspixelflat, chname='pixeflat', cuts=(0.9, 1.1), wcs_match=wcs_match, clear=True)
#     305         viewer, ch = ginga.show_image(self.msillumflat, chname='illumflat', cuts=(0.9, 1.1), wcs_match=wcs_match)
#     306         viewer, ch = ginga.show_image(self.rawflatimg, chname='flat', wcs_match=wcs_match)
#
# /data/Projects/Python/PypeIt/pypeit/ginga.py in show_image(inp, chname, waveimg, bitmask, mask, exten, cuts, clear, wcs_match)
#     148         shell = viewer.shell()
#     149         out = shell.start_global_plugin('WCSMatch')
# --> 150         out = shell.call_global_plugin_method('WCSMatch', 'set_reference_channel', [chname], {})
#     151
#     152     # TODO: I would prefer to change the color map to indicate these
#
# /data/Projects/Python/ginga/ginga/util/grc.py in _call(*args, **kwdargs)
#      32     def __getattr__(self, name):
#      33         def _call(*args, **kwdargs):
# ---> 34             return self._fn(name, *args, **kwdargs)
#      35         return _call
#      36
#
# /data/Projects/Python/ginga/ginga/util/grc.py in call(*args, **kwdargs)
#     190             p_kwdargs = marshall(kwdargs)
#     191
# --> 192             res = self._proxy.dispatch_call(method_name, p_args, p_kwdargs)
#     193
#     194             return unmarshall(res)
#
# /home/xavier/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/xmlrpc/client.py in __call__(self, *args)
#    1110         return _Method(self.__send, "%s.%s" % (self.__name, name))
#    1111     def __call__(self, *args):
# -> 1112         return self.__send(self.__name, args)
#    1113
#    1114 ##
#
# /home/xavier/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/xmlrpc/client.py in __request(self, methodname, params)
#    1450             self.__handler,
#    1451             request,
# -> 1452             verbose=self.__verbose
#    1453             )
#    1454
#
# /home/xavier/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/xmlrpc/client.py in request(self, host, handler, request_body, verbose)
#    1152         for i in (0, 1):
#    1153             try:
# -> 1154                 return self.single_request(host, handler, request_body, verbose)
#    1155             except http.client.RemoteDisconnected:
#    1156                 if i:
#
# /home/xavier/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/xmlrpc/client.py in single_request(self, host, handler, request_body, verbose)
#    1168             if resp.status == 200:
#    1169                 self.verbose = verbose
# -> 1170                 return self.parse_response(resp)
#    1171
#    1172         except Fault:
#
# /home/xavier/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/xmlrpc/client.py in parse_response(self, response)
#    1340         p.close()
#    1341
# -> 1342         return u.close()
#    1343
#    1344 ##
#
# /home/xavier/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/xmlrpc/client.py in close(self)
#     654             raise ResponseError()
#     655         if self._type == "fault":
# --> 656             raise Fault(**self._stack[0])
#     657         return tuple(self._stack)
#     658
#
# Fault: <Fault 1: "<class 'AttributeError'>:'GingaShell' object has no attribute 'call_global_plugin_method'">

# %%
pypeIt.caliBrate.traceSlits.tslits_dict

# %% [markdown]
# ## Slits

# %% [markdown]
# ### Generate trace image

# %%
pypeIt.caliBrate.trace_image_files

# %%
# Instantiate
traceImage = traceimage.TraceImage(pypeitSetup.spectrograph,
                               file_list=pypeIt.caliBrate.trace_image_files, det=1,
                               par=pypeIt.caliBrate.par['traceframe'])

# %%
# Process
mstrace = traceImage.process(bias_subtract='overscan', trim=pypeIt.caliBrate.par['trim'], apply_gain=True)

# %%
traceImage.show()

# %% [markdown]
# ### binarr

# %%
_= pypeIt.caliBrate.traceSlits.make_binarr()

# %%
32*0.0728*2

# %% [markdown]
# ### Plate scale

# %%
# Compute the plate scale in arcsec which is needed to trim short slits
scidx = np.where(pypeIt.caliBrate.fitstbl.find_frames('science', sci_ID=pypeIt.caliBrate.sci_ID))[0][0]
binspatial, binspectral = parse.parse_binning(pypeIt.caliBrate.fitstbl['binning'][scidx])
## Old code: binspatial, binspectral = parse.parse_binning(self.fitstbl['binning'][scidx])
plate_scale = binspatial*pypeitSetup.spectrograph.detector[0]['platescale']
plate_scale

# %% [markdown]
# ### Edgearr

# %%
_= pypeIt.caliBrate.traceSlits._edgearr_from_binarr()

# %%
pypeIt.caliBrate.traceSlits.show('edgearr')

# %% [markdown]
# ### Match edges

# %%
pypeIt.caliBrate.traceSlits._match_edges()

# %% [markdown]
# ### Assign edges

# %%
pypeIt.caliBrate.traceSlits._assign_edges()

# %% [markdown]
# ### Final left/right

# %%
pypeIt.caliBrate.traceSlits._final_left_right()

# %% [markdown]
# ### Mslit magic

# %%
pypeIt.caliBrate.traceSlits._mslit_tcrude()

# %%
pypeIt.caliBrate.traceSlits._mslit_sync()

# %% [markdown]
# ### Fit Edges

# %%
pypeIt.caliBrate.traceSlits._set_lrminx()
pypeIt.caliBrate.traceSlits._fit_edges('left')
pypeIt.caliBrate.traceSlits._fit_edges('right')

# %% [markdown]
# ### Synchronize

# %%
pypeIt.caliBrate.traceSlits._synchronize()

# %% [markdown]
# ### PCA

# %%
pypeIt.caliBrate.traceSlits._pca()

# %%
pypeIt.caliBrate.traceSlits.show('edges')

# %%
pypeIt.caliBrate.traceImage.show()

# %%
pypeIt.caliBrate.traceSlits.show('siglev')

# %%
pypeIt.caliBrate.traceSlits.show('edgearr')

# %%
pypeIt.caliBrate.par

# %% [markdown]
# ----

# %% [markdown]
# ## Wavelengths

# %%
pypeIt.caliBrate.waveCalib.arccen.shape

# %%
from pypeit import debugger

# %%
debugger.plot1d(pypeIt.caliBrate.waveCalib.arccen[:,1])

# %% [markdown]
# ### Save to disk

# %%
tdict = {}
tdict['arccen'] = pypeIt.caliBrate.waveCalib.arccen
#
jdict = ltu.jsonify(tdict)

# %%
ltu.savejson('GMOS_R400_blue.json', jdict)

# %% [markdown]
# ----

# %%
IDpixels = np.array([802.14, 636.01, 487.28, 322.49, 31.8])
IDwave =   np.array([5189.191, 4966.465, 4766.197, 4546.3258, 4159.762])

# %%
dwv = (IDwave-np.roll(IDwave,1))/(IDpixels-np.roll(IDpixels,1))

# %%
dwv/2
